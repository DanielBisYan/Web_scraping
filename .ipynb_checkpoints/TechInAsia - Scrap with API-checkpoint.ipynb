# %%
import requests

# %%
url_normal_posts = "https://www.techinasia.com/wp-json/techinasia/2.0/posts?page=10&per_page=10"
normal_post_header = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "zh-CN,zh;q=0.9,en;q=0.8",
    "Connection": "keep-alive",
    "Host": "www.techinasia.com",
    "Referer": "https://www.techinasia.com/",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36"
}
response = requests.get(
    url=url_normal_posts,
    headers=normal_post_header
)
print(f'statut_code: ', response.status_code)
response.json()
# Out:
# statut_code:  200
# {'total': 38208,
#  'per_page': 10,
#  'current_page': 10,
#  'total_pages': 3821,
#  'posts': [{'id': '633666',
#    'date_gmt': '2019-11-25T03:33:42',
#    'modified_gmt': '2019-11-25T04:03:44',
#    'title': 'Tokopedia may secure up to $1.5b in fundraise before IPO, sources say',
#    'slug': 'tokopedia-secure-1-5b-fundraise-ipo',
#    'status': 'publish',
#    'type': 'post',
#    'link': 'https://www.techinasia.com/tokopedia-secure-1-5b-fundraise-ipo',
# ...

# %%
for post in response.json()['posts']:
    print(f'title: {post["title"]}')
# Out:
# title: Tokopedia may secure up to $1.5b in fundraise before IPO, sources say
# title: Singapore startup Hydroleap raises $1.9m in Wavemaker-led round
# title: Forget e-wallets. Ayannah taps agents to serve the unbanked and it’s growing fast
# title: Suddenly, profitable startups look sexy. Here’s a list.
# title: Why this podcast app targets Netflix, Spotify users
# title: Men, white-collar workers more likely to be affected by AI, research says
# title: Meet the brothers behind this chip startup powering China’s AI ambitions
# title: Tokopedia to offer health products through GoApotik partnership
# title: These are the most active investors in Singapore’s startups
# title: Product search engine BigGo bags $5m in series A round

# %%
url_ten_posts = 'https://www.techinasia.com/wp-json/techinasia/2.0/categories/subscriber-exclusive/posts?page=3&per_page=4'
url_posts_headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "zh-CN,zh;q=0.9,en;q=0.8",
    "Connection": "keep-alive",
    "Host": "www.techinasia.com",
    "Referer": "https://www.techinasia.com/",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36"
}
response_two = requests.get(
    url = url_ten_posts,
    headers = url_posts_headers
)
print(f'statut_code: ', response_two.status_code)
response_two.json()
# Out:
# statut_code:  200
# {'total': 544,
#  'per_page': 4,
#  'current_page': 3,
#  'total_pages': 136,
#  'posts': [{'id': '634081',
#    'date_gmt': '2019-11-29T02:00:33',
#    'modified_gmt': '2019-11-29T01:52:42',
#    'title': 'Southeast Asia’s direct-to-consumer revolution may be underway',
#    'slug': 'southeast-asias-directtoconsumer-revolution-underway',
#    'status': 'publish',
#    'type': 'post',
#    'link': 'https://www.techinasia.com/southeast-asias-directtoconsumer-revolution-underway',
# ...

# %%
for post in response_two.json()['posts']:
    print(f'title: {post["title"]}')
# Out:
# title: Southeast Asia’s direct-to-consumer revolution may be underway
# title: Complete list of tech and startup events in Singapore
# title: These are the most active investors in China’s startups
# title: Here’s why more than a hundred firms signed up for Gnowbe’s learning app
