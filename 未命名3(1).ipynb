# %%
import requests

# %%
url_normal_posts = "https://www.techinasia.com/wp-json/techinasia/2.0/posts?page=1&per_page=10"
normal_post_header = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "zh-CN,zh;q=0.9,en;q=0.8",
    "Connection": "keep-alive",
    "Host": "www.techinasia.com",
    "Referer": "https://www.techinasia.com/",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36"
}
response = requests.get(
    url=url_normal_posts,
    headers=normal_post_header
)
print(f'statut_code: ', response.status_code)
response.json()
# Out:
# statut_code:  200
# {'total': 38177,
#  'per_page': 10,
#  'current_page': 1,
#  'total_pages': 3818,
#  'posts': [{'id': '634231',
#    'date_gmt': '2019-12-02T08:31:43',
#    'modified_gmt': '2019-12-02T08:31:43',
#    'title': 'Singapore agrifood supply chain startup secures funding from SGInnovate',
#    'slug': 'dimuto-secures-funding-sginnovate',
#    'status': 'publish',
#    'type': 'post',
#    'link': 'https://www.techinasia.com/dimuto-secures-funding-sginnovate',
# ...

# %%
for post in response.json()['posts']:
    print(f'title: {post["title"]}')
    # print(f'content: {post["content"]}')
    # you can just try to print out other data from that json response
# Out:
# title: Singapore agrifood supply chain startup secures funding from SGInnovate
# title: Lei Jun steps down as Xiaomi’s China head in management reshuffle
# title: Korean ride-hailing service Tada to face court hearing over regulatory issues
# title: Commentary: Keep your head down and just get shit done
# title: Tribe Accelerator names 9 startups in second cohort
# title: Gojek expands Singapore fleet with Trans-Cab partnership
# title: Wavemaker-backed Lynk raises funds in round led by MassMutual Ventures
# title: A closer look at Indonesia’s furniture and home living startups
# title: Transferwise could become the cross-border engine behind region’s e-wallets
# title: Sea co-founder Gang Ye becomes Singapore’s latest billionaire

# %%
url_highlight_post = "https://www.techinasia.com/wp-json/techinasia/2.0/categories/subscriber-exclusive/posts?page=1&per_page=4"
hightlight_post_header = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "zh-CN,zh;q=0.9,en;q=0.8",
    "Connection": "keep-alive",
    "Host": "www.techinasia.com",
    "Referer": "https://www.techinasia.com/",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36"
}
response = requests.get(
    url=url_highlight_post,
    headers=hightlight_post_header
)
print(f'statut_code: ', response.status_code)
response.json()
# Out:
# statut_code:  200
# {'total': 540,
#  'per_page': 4,
#  'current_page': 1,
#  'total_pages': 135,
#  'posts': [{'id': '634157',
#    'date_gmt': '2019-12-02T01:08:43',
#    'modified_gmt': '2019-12-02T01:47:27',
#    'title': 'Commentary: Keep your head down and just get shit done',
#    'slug': 'get-shit-done',
#    'status': 'publish',
#    'type': 'post',
#    'link': 'https://www.techinasia.com/get-shit-done',
# ...

# %%
for post in response.json()['posts']:
    print(f'title: {post["title"]}')
# Out:
# title: Commentary: Keep your head down and just get shit done
# title: A closer look at Indonesia’s furniture and home living startups
# title: Transferwise could become the cross-border engine behind region’s e-wallets
# title: Southeast Asia’s direct-to-consumer revolution may be underway
